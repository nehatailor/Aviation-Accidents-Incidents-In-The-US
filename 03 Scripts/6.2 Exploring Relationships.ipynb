# %% [markdown]
# /# 6.2 Exploring Relationships

# %% [markdown]
# ### This script contains the following:

# %% [markdown]
# #### 1. Importing Visualization Libraries and Clean Data

# %% [markdown]
# #### 2. Exploring Relationships
#             Correlations
#             Scatterplots
#             Pair Plots
#             Categorical Plots

# %% [markdown]
# ### 1. Importing Visualization Libraries and Clean Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
 # Check matplotlib version
    
matplotlib.__version__
# Out:
# '3.3.4'

# %%
# create charts in the notebook without calling them specifically

# %matplotlib inline

# %%
# Import data - define path

path = r'C:\Users\nehat\OneDrive\Desktop\CF DA Immersion\Achievement 6\Aviation Accidents In The US'

# %%
# Import data set

df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared data', 'AviationData.csv'))

# %% [markdown]
# ### 2. Exploring Relationships

# %% [markdown]
# ### Correlations:

# %%
df.dtypes
# Out:
# Unnamed: 0                  int64
# Investigation.Type         object
# Event.Date                 object
# Country                    object
# Latitude                  float64
# Longitude                 float64
# Airport.Name               object
# Aircraft.Damage            object
# Aircraft.Category          object
# Make                       object
# Model                      object
# Amateur.Built              object
# Number.of.Engines         float64
# Engine.Type                object
# Purpose.of.flight          object
# Total.Fatal.Injuries      float64
# Total.Serious.Injuries    float64
# Total.Minor.Injuries      float64
# Total.Uninjured           float64
# Weather.Condition          object
# Broad.Phase.Of.Flight      object
# City                       object
# State                      object
# InjurySeverityType         object
# dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0 Investigation.Type Event.Date        Country   Latitude  \
# 0           0           Accident  2/16/2021  United States  42.595377
# 1           1           Accident  2/15/2021  United States  18.354444
# 2           2           Accident  2/13/2021  United States  61.336392
# 3           3           Accident  2/12/2021  United States  43.297731
# 4           4           Accident  2/10/2021  United States  27.243723
#
#     Longitude  Airport.Name Aircraft.Damage Aircraft.Category      Make  ...  \
# 0  -89.030245           NaN     Substantial          Airplane  Velocity  ...
# 1  -65.027778           NaN       Destroyed        Helicopter      Bell  ...
# 2 -152.016430           NaN     Substantial          Airplane     Maule  ...
# 3  -89.755693  SAUK-PRAIRIE     Substantial          Airplane    Cessna  ...
# 4  -81.413767           NaN     Substantial          Airplane     Piper  ...
#
#   Purpose.of.flight Total.Fatal.Injuries  Total.Serious.Injuries  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Investigation.Type', 'Event.Date', 'Country', 'Latitude',
#        'Longitude', 'Airport.Name', 'Aircraft.Damage', 'Aircraft.Category',
#        'Make', 'Model', 'Amateur.Built', 'Number.of.Engines', 'Engine.Type',
#        'Purpose.of.flight', 'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Weather.Condition',
#        'Broad.Phase.Of.Flight', 'City', 'State', 'InjurySeverityType'],
#       dtype='object')

# %% [markdown]
# ### Variables suitable for Exploratory Visual Analysis

# %%
# Create subsets of variables used for the analysis

sub = df[['Country', 'Latitude', 'Longitude', 'Airport.Name', 'Aircraft.Damage', 'Aircraft.Category',
       'Make', 'Model', 'Amateur.Built', 'Number.of.Engines', 'Engine.Type',
       'Purpose.of.flight', 'Total.Fatal.Injuries', 'Total.Serious.Injuries',
       'Total.Minor.Injuries', 'Total.Uninjured', 'Weather.Condition',
       'Broad.Phase.Of.Flight', 'City', 'State', 'InjurySeverityType']]

# %%
sub
# Out:
#              Country   Latitude    Longitude  Airport.Name Aircraft.Damage  \
# 0      United States  42.595377   -89.030245           NaN     Substantial
# 1      United States  18.354444   -65.027778           NaN       Destroyed
# 2      United States  61.336392  -152.016430           NaN     Substantial
# 3      United States  43.297731   -89.755693  SAUK-PRAIRIE     Substantial
# 4      United States  27.243723   -81.413767           NaN     Substantial
# ...              ...        ...          ...           ...             ...
# 85971  United States  37.455487 -2655.575588           NaN       Destroyed
# 85972  United States  37.455487 -2655.575588           NaN       Destroyed
# 85973  United States  36.922223   -81.878056           NaN       Destroyed
# 85974  United States  37.455487 -2655.575588           NaN       Destroyed
# 85975  United States  37.455487 -2655.575588           NaN       Destroyed
#
# ...

# %%
# Create a subplot with matplotlib.

f,ax = plt.subplots(figsize=(15,15))

# %%
# Create correlation heatmap in seaborn based on the correlation matrix and subplots

corr = sns.heatmap(sub.corr(), annot = True, ax = ax)

# %%
corr.figure

# %%
# Export correlation heat map.

corr.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'heatmap.png'))

# %% [markdown]
# For the Number of Engines and Total Uninjured, there seems to be a moderate relationship between the 2 variables. So it may be safe to assume that the number of engines relates to the size of the aircraft and therefore affects the number of injured/uninjured during the accident or incident.
#
# There is a weak relationship between the Total Fatal Injuries and Total Serious Injuries which could indicate that out of the higher number of serious injuries, the lower the fatal injuries or the higher the fatal injuries, the lower the serious injuries.
#
# There is also a weak relationship between the Total Serious Injuries and Total Minor Injuries which could indicate that out of the higher number of serious injuries, the lower the minor injuries or the higher the minor injuries, the lower the serious injuries.
#
# Most of the other variables against each other are very to having no relationship with each other.

# %% [markdown]
# ### Scatterplot(s):

# %%
# Create a scatterplot for 'Number of Engines' and 'Total Uninjured' in Seaborn

scatterplot = sns.lmplot(x = 'Total.Uninjured', y = 'Number.of.Engines', data = df)

# %%
# Export scatterplot

scatterplot.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'engines_uninjured.png'))

# %% [markdown]
# From this scatterplot we can see the points are structured and there seems to be a steep, positive relationship between the two variables. We can assume that as the number of the Total Uninjured persons increase the number of engines decrease, meaning the larger the aircraft the greater the number of survivors or uninjured persons.
#
# However, there many points that are away from the line and a significant number of outliers. Becasue of the many points away the correlation coefficient alone is not sufficient to provide an accurate view of the relationship between the variables.
# It gives me an opportunity to delve deeper in to the results and adata set and see why there are many outliers its causes, does the size of the aircraft impact the number of accidents/incidents or fatalities.

# %%
scatterplot1 = sns.lmplot(x = 'Total.Serious.Injuries', y = 'Total.Minor.Injuries', data = df)

# %%
# Export scatterplot

scatterplot1.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'serious_minor.png'))

# %% [markdown]
# This scatter shows positive correlation but the line is not very steep. From the scatterplot we see that the lower the number of total serious injuries there are also low numbers of those with minor injuries.
# There are many outliers and points that are further away from the line.

# %% [markdown]
# ### Pair Plots:

# %%
# Create Pair Plot of the entire data set

aviation = sns.pairplot(sub)

# %% [markdown]
# The pair plot shows many scatterplots plotting categorical variables as we can see the way they are structured.we can see that are the number of engines increase/the larger the aircraft the number of fatalities decrease.
# In other scatterplots looking at fatalites and whether there are serious, minor or uninjured results there seems to be some correlation.
#
# The variables that I want to learn more about are the number of engines, why the number of engines and how the size affects the risk of accidents or incidents. I also want to look at the total number injuries on all levels against the categorical data to see why there is an increase or decrease in injuries on different sized aircrafts.

# %% [markdown]
# ### Categorical Plot:

# %% [markdown]
# Use histograms to visualize the distirbution of variables

# %%
Hist = sns.distplot(df['Number.of.Engines'], bins = 20)
# Out:
# C:\Users\nehat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Export Histogram

Hist.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'num_of_engines.png'))

# %% [markdown]
# Create categories:

# %%
df.loc[df['Number.of.Engines'] < 2, 'Aircraft Size'] = 'Small Aircraft'

# %%
df.loc[(df['Number.of.Engines'] >= 2) & (df['Number.of.Engines'] < 6), 'Aircraft Size'] = 'Medium Aircraft'

# %%
df.loc[df['Number.of.Engines'] >= 6, 'Aircraft Size'] = 'Large Aircraft'

# %%
df['Aircraft Size'].value_counts(dropna = False)
# Out:
# Small Aircraft     74273
# Medium Aircraft    11702
# Large Aircraft         1
# Name: Aircraft Size, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Investigation.Type', 'Event.Date', 'Country', 'Latitude',
#        'Longitude', 'Airport.Name', 'Aircraft.Damage', 'Aircraft.Category',
#        'Make', 'Model', 'Amateur.Built', 'Number.of.Engines', 'Engine.Type',
#        'Purpose.of.flight', 'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Weather.Condition',
#        'Broad.Phase.Of.Flight', 'City', 'State', 'InjurySeverityType',
#        'Aircraft Size'],
#       dtype='object')

# %%
# Create a categorical plot in seaborn using the Aircraft sizes above

sns.set(style = 'ticks')
aviation = sns.catplot(x="Total.Fatal.Injuries", y="Number.of.Engines", hue="Aircraft Size", data=df)

# %%
# Export categorical plot

aviation.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'categorical_plot.png'))

# %% [markdown]
# Most fatalities occur in smaller aircrafts with a single engine followed by injuries occuring on medium sized aircrafts that have engine between 2 and 4.

# %%
sns.set(style = 'ticks')
aviation1 = sns.catplot(x="Investigation.Type", y="Number.of.Engines", hue="Aircraft Size", data=df)

# %%
#Export categorical plot

aviation1.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'engines_aircraftsize.png'))

# %% [markdown]
# There seems to be an equal number of accident and incidents either on small or medium aircrafts that do not have more than 4 engines. The only one accident that has occurred has been on an aircraft with 8 engines.

# %% [markdown]
# At this present moment it is not possible for me to answer many of the questions set forward previously. I need to carry out some deeper investigations in to the other variables to see if there are more answers to the questions.

# %% [markdown]
# #### Hypothesis
#
# What causes the aircrafts with an engine size of 4 or less to have such accidents/incidents?
# What other factors cause these accidents and incidents?

# %%
# Export data set to csv, Prepared Data

df.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'explore_relationships.csv'))
